# %% [markdown]
# <h1>Quiz</h1>

# %% [markdown]
# 1. สร้างกราฟธรรมดาเป็นฟังก์ชั่น Y = X^2 พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["font.family"] = "Tahoma"
plt.rcParams['font.size'] = 14

# %%
x = np.arange(21)
y = x**2
plt.plot(x,y)
plt.title('Exponential graph')
plt.xlabel('x')
plt.ylabel('y = x ** 2')
plt.show()

# %% [markdown]
# 2. สร้างกราฟฟังก์ชั่น Sin (เหมือนตัวอย่าง) พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน เปลี่ยนสีเส้นเป็นสีชมพู

# %%
x = np.arange(21)
y = np.sin(x)
plt.plot(x,y,c='m')
plt.title('Sin graph')
plt.xlabel('x')
plt.ylabel('y = sin x')
plt.show()

# %% [markdown]
# 3. สร้างกราฟธรรมดาเป็นฟังก์ชั่น X = Y^2 พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน เปลี่ยนสีเส้นเป็นสีเขียวอ่อนโดยใช้ค่ารหัสสีฐานสิบหก

# %%
y = np.arange(21)
x = y ** 2
plt.plot(x,y,c='#00FF00')
plt.title('Exponential Graph')
plt.xlabel('x = y ** 2')
plt.ylabel('y')
plt.show()

# %% [markdown]
# 4. สร้างกราฟฟังก์ชั่น Cos (เหมือนตัวอย่าง) พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน เปลี่ยนสีเส้นเป็นสีแดง ใส่ Line Style เป็นเส้น - -

# %%
x = np.arange(21)
y = np.cos(x)
plt.plot(x,y,c='r',ls='--')
plt.title('Cos graph')
plt.xlabel('x')
plt.ylabel('y = cos x')
plt.show()

# %% [markdown]
# 5. สร้างกราฟธรรมดาเป็นฟังก์ชั่น Y = X^2 และ Y = X^3 พล็อตลงในรูปเดียวกัน พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน ใช้สีแดงและน้ำเงินตามลำดับ โดยเส้นแรกใช้วงกลมเป็น marker และเส้นสองใช้สามเหลี่ยมเป็น marker

# %%
x = np.arange(21)
plt.plot(x, x**2,c='r',marker='o')
plt.plot(x, x**3,c='b',marker='^')
plt.title('Graph overlap')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# 6. สร้างกราฟธรรมดาเป็นฟังก์ชั่น Y = X^2 และ X = Y^2 พล็อตลงในรูปเดียวกัน พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน ใช้สีแดงและน้ำเงินตามลำดับ โดยเส้นแรกใช้วงกลมเป็น marker และเส้นสองใช้สามเหลี่ยมเป็น marker และใส่ legend และเพิ่มเส้นตารางข้างหลัง

# %%
x = np.arange(21)
y = x**2
plt.plot(x, y, c='r', marker='o', label='Y = X**2')
plt.plot(y**2, y, c='b', marker='^', label='X = Y^2')
plt.title('Graph overlap')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 7. สร้างกราฟธรรมดาเป็นฟังก์ชั่น X = Y^2 + 4*Y พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน เปลี่ยนสีเส้นเป็นสีเหลืองอ่อนโดยใช้ค่ารหัสสีฐานสิบหก จำกัดแกน X และ Y ให้เหมาะสม

# %%
y = np.arange(21)
x = (y**2)+(4*y)
plt.plot(x, y, c='#FFFF00')
plt.title('Graph limit')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(100,300)
plt.ylim(5,15)
plt.show()

# %% [markdown]
# 8. สร้างกราฟใหญ่ด้วยสมการ X = Y^3 และกราฟเล็กด้วย Y = X^2 + 2 พล็อตลงในรูปเดียวกัน พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน และใส่ legend

# %%
y1 = np.arange(21)
x1 = y1**3
x2 = np.arange(21)
y2 = x2**2+2
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax1.plot(x1,y1,c='r',label='X = Y ** 3')
ax1.set_title('Big graph')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend()
ax2 = fig.add_axes([0.4,0.1,0.5,0.5])
ax2.plot(x2,y2,c='b',label='Y = X**2 + 2')
ax2.set_title('Small graph')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.legend()
plt.show()

# %% [markdown]
# ให้ import ไฟล์ titanic ไฟล์เดิมจากบทเรียน Pandas เข้าสู่ Jupyter Notebook สามารถใช้ Pandas มาร่วมทำด้วย

# %%
df = pd.read_csv('..\\4. Pandas\\train.csv')

# %% [markdown]
# 9. ให้หาอัตราส่วนตั๋วโดยสารชั้น 1 2 3 และพล็อตเป็น Pie chart

# %%
plt.pie(df['Pclass'].value_counts().sort_index(), labels=['ตั๋วโดยสารขั้น 1', 'ตั๋วโดยสารชั้น 2', 'ตั๋วโดยสารชั้น 3'])
plt.show()

# %% [markdown]
# 10. ให้หาอัตราส่วนของจุดหมายปลายทาง (Embark) และพล็อต Pie chat พร้อมทั้งให้ Queenstown เป็น explode

# %%
plt.pie(df['Embarked'].value_counts().sort_index(),
        labels=['Cherbourg', 'Queenstown', 'Southampton'], explode=[0,0.15,0])
plt.show()

# %% [markdown]
# 11. นำราคาตั๋วโดยสารทั้งหมดมาหา histogram

# %%
plt.hist(df['Fare'],bins=200)
plt.title('Historam graph (Fare)')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 12. สร้างพล็อตแบบกระจายโดยให้อายุเป็นแกน X และ ราคาตั๋วโดยสารเป็นแกน Y

# %%
plt.scatter(df['Age'], df['Fare'])
plt.title('Scatter plot graph (Age : Fare)')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# 13. สร้าง bar chart โดยใช้ข้อมูลจากราคาตั๋วโดยสารเฉลี่ยแต่ละชั้น

# %%
plt.bar([1,2,3],df.groupby('Pclass')['Fare'].mean())
plt.title('Bar graph (Pclass : Avg fare)')
plt.xlabel('Pclass')
plt.ylabel('Avg fare')
plt.show()

# %% [markdown]
# 14. สร้าง bar chart โดยใช้ข้อมูลจากราคาตั๋วโดยสารต่ออายุของผู้โดยสาร

# %%
plt.bar(df['Age'],df['Fare'])
plt.title('Bar graph (Age : Fare)')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# 15. สร้าง bar chart โดยใช้ข้อมูลผู้ที่นามสกุลซ้ำกัน โดยความถี่เป็นแกน Y

# %%
df['Lastname'] = df['Name'].str.split(',').str[0]
duplastname = df['Lastname'].value_counts()[df['Lastname'].value_counts() > 1]
plt.bar(sorted(duplastname.unique()), duplastname.value_counts().sort_index())
plt.title('Graph')
plt.xlabel('จำนวนคนที่นามสกุลซ้ำ')
plt.ylabel('ความถี่')
plt.show()

# %%
df['Lastname'] = df['Name'].str.split(',').str[0]
duplastname = df['Lastname'].value_counts()[df['Lastname'].value_counts() > 1]
plt.figure(figsize=(30,10))
plt.bar(duplastname.index.sort_values(), duplastname.sort_index())
plt.title('Graph')
plt.xticks(rotation=90)
plt.xlabel('Lastname')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 16. (Optional) สร้างหลายกราฟในรูปเดียว โดยมีสองคอลัมน์ คอลัมน์แรกมีสามแถว คอลัมน์สองมีสองแถว พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน โดยสมการแต่ละกราฟสามารถคิดเองได้โดยใช้ข้อมูลจากไฟล์ titanic และไม่ต้องซ้ำกัน

# %%
plt.figure(figsize=(20,10))
fig = plt.figure(figsize=(10,20))
ax1 = fig.add_subplot(321,title='Graph Sex',xlabel='Sex',ylabel='Frequency')
ax1.bar(df['Sex'].unique(),df['Sex'].value_counts(),color='c')

ax2 = fig.add_subplot(323,title='Graph Age',xlabel='Age',ylabel='Frequency')
ax2.hist(df['Age'],bins=10,color='m')

ax3 = fig.add_subplot(325,title='Graph Pclass',xlabel='Pclass',ylabel='Frequency')
ax3.bar(df['Pclass'].unique(),df['Pclass'].value_counts(),color='y')

ax4 = fig.add_subplot(222,title='Graph (PassengerId : Age)',xlabel='PassengerId',ylabel='Age')
ax4.scatter(df['PassengerId'],df['Age'],c='g')

ax5 = fig.add_subplot(224,title='Graph Survived')
ax5.pie(df['Survived'].value_counts(),labels=['เสียชีวิต', 'รอดชีวิต'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ---
